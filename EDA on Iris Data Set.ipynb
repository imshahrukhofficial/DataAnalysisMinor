# %% [markdown]
# # Data Discription
#
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository. Dataset consist of 150 different flowers, or 50 each from three different species of iris (Iris setosa, Iris versicolor, and Iris virginica). It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
# Id
#
# SepalLengthCm
#
# SepalWidthCm
#
# PetalLengthCm
#
# PetalWidthCm
#
# Species

# %%
from IPython.display import Image
Image(url= 'https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png')
# Out:
# <img src="https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png"/>

# %%
#    Importing some necessory libraries for EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading our Data and setting 'ID' as index column

# %%
iris = pd.read_csv("C:\\Users\\Shah Rukh\\Downloads\\iris.csv",index_col = "Id")

# %% [markdown]
# # Basic Analysis

# %%
iris.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Data Separation

# %% [markdown]
# ### Iris Setosa

# %%
setosa = iris.loc[(iris.Species == "Iris-setosa")]

# %% [markdown]
# ### Iris Versicolor

# %%
versi = iris.loc[(iris.Species == "Iris-versicolor")]

# %% [markdown]
# ### Iris Verginica

# %%
virgi = iris.loc[(iris.Species == "Iris-virginica")]

# %% [markdown]
# ##  Analysis on Iris Setosa

# %%
setosa.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
setosa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 5 columns):
# SepalLengthCm    50 non-null float64
# SepalWidthCm     50 non-null float64
# PetalLengthCm    50 non-null float64
# PetalWidthCm     50 non-null float64
# Species          50 non-null object
# dtypes: float64(4), object(1)
# memory usage: 2.3+ KB

# %%
setosa.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         5.00600      3.418000       1.464000       0.24400
# std          0.35249      0.381024       0.173511       0.10721
# min          4.30000      2.300000       1.000000       0.10000
# 25%          4.80000      3.125000       1.400000       0.20000
# 50%          5.00000      3.400000       1.500000       0.20000
# 75%          5.20000      3.675000       1.575000       0.30000
# max          5.80000      4.400000       1.900000       0.60000

# %% [markdown]
# Iris setosa has 50 rows

# %%
setosa.shape
# Out:
# (50, 5)

# %%
sns.kdeplot(data = setosa.iloc[:,:4], shade = True, palette = ("red","blue","green","yellow"))

# %% [markdown]
# From the 2nd(mean) row of above chart and below plot we can see the average value of sepal length,sepal width,petal length and petal width of Iris-Setosa flower

# %%
# Style
sns.set_style("whitegrid")
# Plot size
plt.figure(figsize=(7, 8))
# Box plot
sns.boxplot(data = setosa)

# %%
sns.jointplot(x = setosa["SepalLengthCm"], y = setosa["SepalWidthCm"], kind = "kde", color = "red", shade = "dark")

# %%
sns.jointplot(x = setosa["PetalLengthCm"], y = setosa["PetalWidthCm"], kind = "kde", color = "red", shade = "dark")

# %% [markdown]
# ## Analysis on Iris Versicolor

# %%
versi.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# Id
# 51            7.0           3.2            4.7           1.4  Iris-versicolor
# 52            6.4           3.2            4.5           1.5  Iris-versicolor
# 53            6.9           3.1            4.9           1.5  Iris-versicolor
# 54            5.5           2.3            4.0           1.3  Iris-versicolor
# 55            6.5           2.8            4.6           1.5  Iris-versicolor

# %%
versi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 51 to 100
# Data columns (total 5 columns):
# SepalLengthCm    50 non-null float64
# SepalWidthCm     50 non-null float64
# PetalLengthCm    50 non-null float64
# PetalWidthCm     50 non-null float64
# Species          50 non-null object
# dtypes: float64(4), object(1)
# memory usage: 2.3+ KB

# %%
versi.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count      50.000000     50.000000      50.000000     50.000000
# mean        5.936000      2.770000       4.260000      1.326000
# std         0.516171      0.313798       0.469911      0.197753
# min         4.900000      2.000000       3.000000      1.000000
# 25%         5.600000      2.525000       4.000000      1.200000
# 50%         5.900000      2.800000       4.350000      1.300000
# 75%         6.300000      3.000000       4.600000      1.500000
# max         7.000000      3.400000       5.100000      1.800000

# %% [markdown]
# Iris Versicolor has 50 rows

# %%
versi.shape
# Out:
# (50, 5)

# %%
sns.kdeplot(data = versi.iloc[:,:4], shade = True, palette = ("red","blue","green","yellow"))

# %% [markdown]
# From the 2nd(mean) row of above chart and below plot we can see the average value of sepal length,sepal width,petal length and petal width of Iris-Versicolor flower

# %%
sns.set_style("whitegrid")
plt.figure(figsize = (7,8))
sns.boxplot(data = versi)

# %%
sns.jointplot(x = versi["SepalLengthCm"], y = versi["SepalWidthCm"], kind = "kde", color = "cyan", shade = "dark")

# %%
sns.jointplot(x = versi["PetalLengthCm"], y = versi["PetalWidthCm"], kind = "kde", color = "cyan", shade = "dark")

# %% [markdown]
# ## Analysis on Iris Verginica

# %%
virgi.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 101            6.3           3.3            6.0           2.5  Iris-virginica
# 102            5.8           2.7            5.1           1.9  Iris-virginica
# 103            7.1           3.0            5.9           2.1  Iris-virginica
# 104            6.3           2.9            5.6           1.8  Iris-virginica
# 105            6.5           3.0            5.8           2.2  Iris-virginica

# %%
virgi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 101 to 150
# Data columns (total 5 columns):
# SepalLengthCm    50 non-null float64
# SepalWidthCm     50 non-null float64
# PetalLengthCm    50 non-null float64
# PetalWidthCm     50 non-null float64
# Species          50 non-null object
# dtypes: float64(4), object(1)
# memory usage: 2.3+ KB

# %%
virgi.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         6.58800      2.974000       5.552000       2.02600
# std          0.63588      0.322497       0.551895       0.27465
# min          4.90000      2.200000       4.500000       1.40000
# 25%          6.22500      2.800000       5.100000       1.80000
# 50%          6.50000      3.000000       5.550000       2.00000
# 75%          6.90000      3.175000       5.875000       2.30000
# max          7.90000      3.800000       6.900000       2.50000

# %% [markdown]
# Iris Virginica has 50 rows

# %%
virgi.shape
# Out:
# (50, 5)

# %%
sns.kdeplot(data = virgi.iloc[:,:4], shade = True, palette = ("red","blue","green","yellow"))

# %% [markdown]
# From the 2nd(mean) row of above chart and below plot we can see the average value of sepal length,sepal width,petal length and petal width of Iris-Virginica flower

# %%
sns.set_style("whitegrid")
plt.figure(figsize = (7,8))
sns.boxplot(data = virgi)

# %%
sns.jointplot(x = virgi["SepalLengthCm"], y = virgi["SepalWidthCm"], kind = "kde", color = "purple", shade = "dark")

# %%
sns.jointplot(x = virgi["PetalLengthCm"], y = virgi["PetalWidthCm"], kind = "kde", color = "purple", shade = "dark")

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Sepal Length

# %% [markdown]
# Scatter Plot

# %%
# Plot Size
plt.figure(figsize = (6,3))
# Plot Title
plt.title("Sepal length of each flower with specie type")
# Plot
sns.scatterplot(x = iris.index, y = iris["SepalLengthCm"], hue = iris["Species"], palette = ("red","cyan","purple"))

# %% [markdown]
# Line Chart

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Sepal length of each flower with specie type")
# Plot
sns.lineplot(x = iris.index, y = iris["SepalLengthCm"], hue = iris["Species"], palette = ("red","cyan","purple"))

# %% [markdown]
# Box Plot

# %%
# Plot Size
plt.figure(figsize = (7,5))
# Plot Title
plt.title("Sepal length of each flower with specie type")
# Plot
sns.boxplot(x = iris["Species"], y = iris["SepalLengthCm"], hue = iris["Species"], palette=("red","cyan","purple"))

# %% [markdown]
# Swarm Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Sepal length of each flower with specie type")
# Plot
sns.swarmplot(x = iris["Species"], y = iris["SepalLengthCm"], hue = iris["Species"], palette = ("red","cyan","purple"))

# %% [markdown]
# ## Sepal Width

# %% [markdown]
# Scatter Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Sepal Width of each flower with specie type")
# Plot
sns.scatterplot(x = iris.index, y = iris["SepalWidthCm"], hue = iris["Species"], palette = ("orange","indigo","lawngreen"))

# %% [markdown]
# Line Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Sepal Width of each flower with specie type")
# Plot
sns.lineplot(x = iris.index, y = iris["SepalWidthCm"], hue = iris["Species"], palette = ("orange","indigo","lawngreen"))

# %% [markdown]
# Box Plot

# %%
# Plot Size
plt.figure(figsize = (7,5))
# Plot Title
plt.title("Sepal Width of each flower with specie type")
# Plot
sns.boxplot(x = iris["Species"],y = iris["SepalWidthCm"], hue = iris["Species"], palette = ("orange","indigo","lawngreen"))

# %% [markdown]
# Swarm Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Sepal Width of each flower with specie type")
# Plot
sns.swarmplot(x = iris["Species"], y = iris["SepalWidthCm"], hue = iris["Species"], palette = ("orange","indigo","lawngreen"))

# %% [markdown]
# ## Petal Length

# %% [markdown]
# Scatter Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Petal length of each flower with specie type")
# Plot
sns.scatterplot(x = iris.index, y = iris["PetalLengthCm"], hue = iris["Species"], palette = ("darkblue","gold","darkgrey"))

# %% [markdown]
# Line Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Petal length of each flower with specie type")
# Plot
sns.lineplot(x = iris.index, y = iris["PetalLengthCm"], hue = iris["Species"], palette = ("darkblue","gold","darkgrey"))

# %% [markdown]
# Box Plot

# %%
# Plot Size
plt.figure(figsize = (7,5))
# Plot Title
plt.title("Petal length of each flower with specie type")
# Plot
sns.boxplot(x = iris["Species"], y = iris["PetalLengthCm"], hue = iris["Species"], palette = ("darkblue","gold","darkgrey"))

# %% [markdown]
# Swarm Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Petal length of each flower with specie type")
# Plot
sns.swarmplot(x = iris["Species"], y = iris["PetalLengthCm"], hue = iris["Species"], palette = ("darkblue","gold","darkgrey"))

# %% [markdown]
# ## Petal Width

# %% [markdown]
# Scatter Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Petal Width of each flower with specie type")
# Plot
sns.scatterplot(x = iris.index, y = iris["PetalWidthCm"], hue = iris["Species"], palette = ("deeppink","black","teal"))

# %% [markdown]
# Line Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Petal Width of each flower with specie type")
# Plot
sns.lineplot(x = iris.index, y = iris["PetalWidthCm"], hue = iris["Species"], palette = ("deeppink","black","teal"))

# %% [markdown]
# Box Plot

# %%
# Plot Size
plt.figure(figsize = (7,5))
# Plot Title
plt.title("Petal Width of each flower with specie type")
# Plot
sns.boxplot(x = iris["Species"], y = iris["PetalWidthCm"], hue = iris["Species"], palette = ("deeppink","black","teal"))

# %% [markdown]
# Swarm Plot

# %%
# Plot Size
plt.figure(figsize = (6,4))
# Plot Title
plt.title("Petal Width of each flower with specie type")
# Plot
sns.swarmplot(x = iris["Species"], y = iris["PetalWidthCm"], hue = iris["Species"], palette = ("deeppink","black","teal"))

# %% [markdown]
# - In this EDA, We can see the Basic information about the Iris dataset like mean, median, min, max, basic visualization outliers and missing values.
